# %%
import os
import pandas

# %%
df1=pandas.read_excel("supermarkets.xlxs")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 df1=pandas.read_excel("supermarkets.xlxs")
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# ...

# %%
listdir()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 listdir()
#
# NameError: name 'listdir' is not defined

# %%
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets.json',
#  'Untitled1.ipynb']

# %%
df1=pandas.read_excel("supermarkets.xlsx")

# %%
df1
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3=pandas.read_excel("supermarkets.xlsx")
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3.ilock[1:3,1:3]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 df3.ilock[1:3,1:3]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ilock'

# %%
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3.iloc[1:3,1:3]
# Out:
#           Address           City
# 1  735 Dolores St  San Francisco
# 2     332 Hill St  San Francisco

# %%
df3.iloc[1:4, 1:4]
# Out:
#           Address           City             State
# 1  735 Dolores St  San Francisco          CA 94119
# 2     332 Hill St  San Francisco  California 94114
# 3    3995 23rd St  San Francisco          CA 94114

# %%
df3.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Supermarket Name',
#        'Number of Employees'],
#       dtype='object')

# %%
df3["Continent"]=df3.shape[0]*["North America"]

# %%
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees      Continent
# 0          Madeira                    8  North America
# 1      Bready Shop                   15  North America
# 2      Super River                   25  North America
# 3       Ben's Shop                   10  North America
# 4          Sanchez                   12  North America
# 5       Richvalley                   20  North America

# %%
df3['Continent']=df3["Country"]+
df3
# Out:
#   Cell In [16], line 1
#     df3['Continent']=df3["Country"]+
#                                     ^
# SyntaxError: invalid syntax

# %%
df3['Continent']=df3["Country"]
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees Continent
# 0          Madeira                    8       USA
# 1      Bready Shop                   15       USA
# 2      Super River                   25       USA
# 3       Ben's Shop                   10       USA
# 4          Sanchez                   12       USA
# 5       Richvalley                   20       USA

# %%
df3['Continent']=df3["Country"]+ "," + "North America"
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees          Continent
# 0          Madeira                    8  USA,North America
# 1      Bready Shop                   15  USA,North America
# 2      Super River                   25  USA,North America
# 3       Ben's Shop                   10  USA,North America
# 4          Sanchez                   12  USA,North America
# 5       Richvalley                   20  USA,North America

# %%
df3_t = df3.T

# %%
df3_t
# Out:
#                                      0                  1                  2  \
# ID                                   1                  2                  3
# Address                   3666 21st St     735 Dolores St        332 Hill St
# City                     San Francisco      San Francisco      San Francisco
# State                         CA 94114           CA 94119   California 94114
# Country                            USA                USA                USA
# Supermarket Name               Madeira        Bready Shop        Super River
# Number of Employees                  8                 15                 25
# Continent            USA,North America  USA,North America  USA,North America
#
#                                      3                  4                  5
# ID                                   4                  5                  6
# Address                   3995 23rd St    1056 Sanchez St    551 Alvarado St
# ...

# %%
df3_t
# Out:
#                                      0                  1                  2  \
# ID                                   1                  2                  3
# Address                   3666 21st St     735 Dolores St        332 Hill St
# City                     San Francisco      San Francisco      San Francisco
# State                         CA 94114           CA 94119   California 94114
# Country                            USA                USA                USA
# Supermarket Name               Madeira        Bready Shop        Super River
# Number of Employees                  8                 15                 25
# Continent            USA,North America  USA,North America  USA,North America
#
#                                      3                  4                  5  \
# ID                                   4                  5                  6
# Address                   3995 23rd St    1056 Sanchez St    551 Alvarado St
# ...

# %%
df3 = df3_t.T

# %%
df3
# Out:
#            ID          Address           City             State Country  \
# 0           1     3666 21st St  San Francisco          CA 94114     USA
# 1           2   735 Dolores St  San Francisco          CA 94119     USA
# 2           3      332 Hill St  San Francisco  California 94114     USA
# 3           4     3995 23rd St  San Francisco          CA 94114     USA
# 4           5  1056 Sanchez St  San Francisco        California     USA
# 5           6  551 Alvarado St  San Francisco          CA 94114     USA
# My Address  0          My city     My Country                10       6
#
#            Supermarket Name Number of Employees          Continent
# 0                   Madeira                   8  USA,North America
# 1               Bready Shop                  15  USA,North America
# 2               Super River                  25  USA,North America
# 3                Ben's Shop                  10  USA,North America
# ...

# %%
df3_t["My Address"]=[,"","","","","",,""]
# Out:
#   Cell In [42], line 1
#     df3_t["My Address"]=[,"","","","","",,""]
#                          ^
# SyntaxError: invalid syntax

# %%
df3 = df3_t.T

# %%
df3
# Out:
#             ID          Address           City             State  Country  \
# 0            1     3666 21st St  San Francisco          CA 94114      USA
# 1            2   735 Dolores St  San Francisco          CA 94119      USA
# 2            3      332 Hill St  San Francisco  California 94114      USA
# 3            4     3995 23rd St  San Francisco          CA 94114      USA
# 4            5  1056 Sanchez St  San Francisco        California      USA
# 5            6  551 Alvarado St  San Francisco          CA 94114      USA
# My Address  10          Address           city             State  Country
# 6           10          Address           city             State  Country
#
#            Supermarket Name Number of Employees          Continent
# 0                   Madeira                   8  USA,North America
# 1               Bready Shop                  15  USA,North America
# 2               Super River                  25  USA,North America
# ...

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
import geopy

# %%
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'Geocodio',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
n=nom.geocode("453 19th ter NE, Centerpoint, Al 35215")

# %%
n.longitude
# Out:
# -86.66961996195354

# %%
n.latitude
# Out:
# 33.63878599071819

# %%
type(n)
# Out:
# geopy.location.Location

# %%
df1
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df1["Address"]=df1["Address"]+ ",  "+ df1["State"]+ ", "+ df1["Country"]
df1
# Out:
#    ID                              Address           City             State  \
# 0   1         3666 21st St,  CA 94114, USA  San Francisco          CA 94114
# 1   2       735 Dolores St,  CA 94119, USA  San Francisco          CA 94119
# 2   3  332 Hill St,  California 94114, USA  San Francisco  California 94114
# 3   4         3995 23rd St,  CA 94114, USA  San Francisco          CA 94114
# 4   5    1056 Sanchez St,  California, USA  San Francisco        California
# 5   6      551 Alvarado St,  CA 94114, USA  San Francisco          CA 94114
#
#   Country Supermarket Name  Number of Employees
# 0     USA          Madeira                    8
# 1     USA      Bready Shop                   15
# 2     USA      Super River                   25
# 3     USA       Ben's Shop                   10
# 4     USA          Sanchez                   12
# 5     USA       Richvalley                   20

# %%
df1["Coordinates"]=df1["Address"].apply(nom.geocode)
df1
# Out:
#    ID                              Address           City             State  \
# 0   1         3666 21st St,  CA 94114, USA  San Francisco          CA 94114
# 1   2       735 Dolores St,  CA 94119, USA  San Francisco          CA 94119
# 2   3  332 Hill St,  California 94114, USA  San Francisco  California 94114
# 3   4         3995 23rd St,  CA 94114, USA  San Francisco          CA 94114
# 4   5    1056 Sanchez St,  California, USA  San Francisco        California
# 5   6      551 Alvarado St,  CA 94114, USA  San Francisco          CA 94114
#
#   Country Supermarket Name  Number of Employees  \
# 0     USA          Madeira                    8
# 1     USA      Bready Shop                   15
# 2     USA      Super River                   25
# 3     USA       Ben's Shop                   10
# 4     USA          Sanchez                   12
# 5     USA       Richvalley                   20
#
#                                          Coordinates
# ...

# %%
df1.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (94119, San Francisco, California, (37.7922150...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df1.Coordinates[0].latitude
df1.Coordinates[0].longitude
# Out:
# -122.42941101194798

# %%
df1["Latitude"]=df1["Coordinates"].apply(lambda x: x.latitude)
df1
# Out:
#    ID                              Address           City             State  \
# 0   1         3666 21st St,  CA 94114, USA  San Francisco          CA 94114
# 1   2       735 Dolores St,  CA 94119, USA  San Francisco          CA 94119
# 2   3  332 Hill St,  California 94114, USA  San Francisco  California 94114
# 3   4         3995 23rd St,  CA 94114, USA  San Francisco          CA 94114
# 4   5    1056 Sanchez St,  California, USA  San Francisco        California
# 5   6      551 Alvarado St,  CA 94114, USA  San Francisco          CA 94114
#
#   Country Supermarket Name  Number of Employees  \
# 0     USA          Madeira                    8
# 1     USA      Bready Shop                   15
# 2     USA      Super River                   25
# 3     USA       Ben's Shop                   10
# 4     USA          Sanchez                   12
# 5     USA       Richvalley                   20
#
#                                          Coordinates   Latitude
# ...

# %%
df1["Longitude"]=df1["Coordinates"].apply(lambda y: y.longitude)
df1
# Out:
#    ID                              Address           City             State  \
# 0   1         3666 21st St,  CA 94114, USA  San Francisco          CA 94114
# 1   2       735 Dolores St,  CA 94119, USA  San Francisco          CA 94119
# 2   3  332 Hill St,  California 94114, USA  San Francisco  California 94114
# 3   4         3995 23rd St,  CA 94114, USA  San Francisco          CA 94114
# 4   5    1056 Sanchez St,  California, USA  San Francisco        California
# 5   6      551 Alvarado St,  CA 94114, USA  San Francisco          CA 94114
#
#   Country Supermarket Name  Number of Employees  \
# 0     USA          Madeira                    8
# 1     USA      Bready Shop                   15
# 2     USA      Super River                   25
# 3     USA       Ben's Shop                   10
# 4     USA          Sanchez                   12
# 5     USA       Richvalley                   20
#
#                                          Coordinates   Latitude   Longitude
# ...
